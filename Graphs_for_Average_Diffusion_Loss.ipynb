# %% [markdown]
# <a href="https://colab.research.google.com/github/ChirayuSalgarkar/SafeDiffuseTraj/blob/main/Graphs_for_Average_Diffusion_Loss.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x1 = []

# %%
data = [
{'avg_loss_diffusion': 0.4475486104786396, 'avg_loss_classifier': 279.73805172252656, 'gradient_steps': 1000},
{'avg_loss_diffusion': 0.3134322925657034, 'avg_loss_classifier': 126.94934607028961, 'gradient_steps': 2000},
{'avg_loss_diffusion': 0.28053972019255163, 'avg_loss_classifier': 119.56772999811173, 'gradient_steps': 3000},
{'avg_loss_diffusion': 0.26054801693558693, 'avg_loss_classifier': 115.327469353199, 'gradient_steps': 4000},
{'avg_loss_diffusion': 0.24662649132311343, 'avg_loss_classifier': 106.97808440876007, 'gradient_steps': 5000},
{'avg_loss_diffusion': 0.23689504565298558, 'avg_loss_classifier': 104.7623509349823, 'gradient_steps': 6000},
{'avg_loss_diffusion': 0.22992334060370923, 'avg_loss_classifier': 102.24795291900635, 'gradient_steps': 7000},
{'avg_loss_diffusion': 0.22160322627425194, 'avg_loss_classifier': 97.35895714521408, 'gradient_steps': 8000},
{'avg_loss_diffusion': 0.21868231601268054, 'avg_loss_classifier': 92.72323830318452, 'gradient_steps': 9000},
{'avg_loss_diffusion': 0.21478056119382383, 'avg_loss_classifier': 92.61212872362137, 'gradient_steps': 10000},
{'avg_loss_diffusion': 0.21305153916776182, 'avg_loss_classifier': 91.4811722331047, 'gradient_steps': 11000},
{'avg_loss_diffusion': 0.21240008133649826, 'avg_loss_classifier': 88.71665014410019, 'gradient_steps': 12000},
{'avg_loss_diffusion': 0.20662225578725338, 'avg_loss_classifier': 84.06792638874055, 'gradient_steps': 13000},
{'avg_loss_diffusion': 0.2040228815227747, 'avg_loss_classifier': 84.64940871167182, 'gradient_steps': 14000},
{'avg_loss_diffusion': 0.20264464879781008, 'avg_loss_classifier': 83.61928134107589, 'gradient_steps': 15000},
{'avg_loss_diffusion': 0.2021517512127757, 'avg_loss_classifier': 88.06326619577408, 'gradient_steps': 16000},
{'avg_loss_diffusion': 0.20043382102251053, 'avg_loss_classifier': 81.80834152436256, 'gradient_steps': 17000},
{'avg_loss_diffusion': 0.19937334553897382, 'avg_loss_classifier': 80.01369235897064, 'gradient_steps': 18000},
{'avg_loss_diffusion': 0.19845804070681333, 'avg_loss_classifier': 81.18055818510055, 'gradient_steps': 19000},
{'avg_loss_diffusion': 0.19601979146897794, 'avg_loss_classifier': 73.40861163473129, 'gradient_steps': 20000},
{'avg_loss_diffusion': 0.195271478690207, 'avg_loss_classifier': 77.20147848820686, 'gradient_steps': 21000},
{'avg_loss_diffusion': 0.19282712675631047, 'avg_loss_classifier': 74.58546297693252, 'gradient_steps': 22000},
{'avg_loss_diffusion': 0.19344953705370427, 'avg_loss_classifier': 73.58166451931, 'gradient_steps': 23000},
{'avg_loss_diffusion': 0.1918246569260955, 'avg_loss_classifier': 75.22007795214653, 'gradient_steps': 24000},
{'avg_loss_diffusion': 0.1912419413551688, 'avg_loss_classifier': 74.08149750041962, 'gradient_steps': 25000},
{'avg_loss_diffusion': 0.19104137103259564, 'avg_loss_classifier': 72.33008003616332, 'gradient_steps': 26000},
{'avg_loss_diffusion': 0.1885228697285056, 'avg_loss_classifier': 70.88795485782623, 'gradient_steps': 27000},
{'avg_loss_diffusion': 0.18960345860570668, 'avg_loss_classifier': 70.44902669334411, 'gradient_steps': 28000},
{'avg_loss_diffusion': 0.18719525440037252, 'avg_loss_classifier': 72.85680262804031, 'gradient_steps': 29000},
{'avg_loss_diffusion': 0.18711430323123932, 'avg_loss_classifier': 72.67877454066277, 'gradient_steps': 30000},
]

# %%
data2 = [
{'avg_loss_diffusion': 0.4475486104786396, 'avg_loss_classifier': 282.06147841119764, 'gradient_steps': 1000},
{'avg_loss_diffusion': 0.3134322925657034, 'avg_loss_classifier': 126.8775853099823, 'gradient_steps': 2000},
{'avg_loss_diffusion': 0.28053972019255163, 'avg_loss_classifier': 120.98830982351303, 'gradient_steps': 3000},
{'avg_loss_diffusion': 0.26054801693558693, 'avg_loss_classifier': 117.16498756885528, 'gradient_steps': 4000},
{'avg_loss_diffusion': 0.24662649132311343, 'avg_loss_classifier': 108.62160791015626, 'gradient_steps': 5000},
{'avg_loss_diffusion': 0.23689504565298558, 'avg_loss_classifier': 108.5016200990677, 'gradient_steps': 6000},
{'avg_loss_diffusion': 0.22992334060370923, 'avg_loss_classifier': 102.58782608127594, 'gradient_steps': 7000},
{'avg_loss_diffusion': 0.22160322627425194, 'avg_loss_classifier': 96.80363497447968, 'gradient_steps': 8000},
{'avg_loss_diffusion': 0.21868231601268054, 'avg_loss_classifier': 95.98050507974625, 'gradient_steps': 9000},
{'avg_loss_diffusion': 0.21478056119382383, 'avg_loss_classifier': 93.24159127235413, 'gradient_steps': 10000},
{'avg_loss_diffusion': 0.21305153916776182, 'avg_loss_classifier': 91.43928422355651, 'gradient_steps': 11000},
{'avg_loss_diffusion': 0.21240008133649826, 'avg_loss_classifier': 89.10160966205596, 'gradient_steps': 12000},
{'avg_loss_diffusion': 0.20662225578725338, 'avg_loss_classifier': 85.55658843946456, 'gradient_steps': 13000},
{'avg_loss_diffusion': 0.2040228815227747, 'avg_loss_classifier': 85.13717959117889, 'gradient_steps': 14000},
{'avg_loss_diffusion': 0.20264464879781008, 'avg_loss_classifier': 81.0801267619133, 'gradient_steps': 15000},
{'avg_loss_diffusion': 0.2021517512127757, 'avg_loss_classifier': 86.99062787103652, 'gradient_steps': 16000},
{'avg_loss_diffusion': 0.20043382102251053, 'avg_loss_classifier': 81.65185268163681, 'gradient_steps': 17000},
{'avg_loss_diffusion': 0.19937334553897382, 'avg_loss_classifier': 79.43472961568833, 'gradient_steps': 18000},
{'avg_loss_diffusion': 0.19845804070681333, 'avg_loss_classifier': 80.75299419498444, 'gradient_steps': 19000},
{'avg_loss_diffusion': 0.19601979146897794, 'avg_loss_classifier': 73.92094570350648, 'gradient_steps': 20000},
{'avg_loss_diffusion': 0.195271478690207, 'avg_loss_classifier': 76.97242634248734, 'gradient_steps': 21000},
{'avg_loss_diffusion': 0.19282712675631047, 'avg_loss_classifier': 74.96954912948608, 'gradient_steps': 22000},
{'avg_loss_diffusion': 0.19344953705370427, 'avg_loss_classifier': 72.86324003124237, 'gradient_steps': 23000},
{'avg_loss_diffusion': 0.1918246569260955, 'avg_loss_classifier': 76.84121114253998, 'gradient_steps': 24000},
{'avg_loss_diffusion': 0.1912419413551688, 'avg_loss_classifier': 75.49171533370018, 'gradient_steps': 25000},
{'avg_loss_diffusion': 0.19104137103259564, 'avg_loss_classifier': 71.65418312120438, 'gradient_steps': 26000},
{'avg_loss_diffusion': 0.1885228697285056, 'avg_loss_classifier': 70.32200620889664, 'gradient_steps': 27000},
{'avg_loss_diffusion': 0.18960345860570668, 'avg_loss_classifier': 70.14182339668274, 'gradient_steps': 28000},
{'avg_loss_diffusion': 0.18719525440037252, 'avg_loss_classifier': 73.35639378452301, 'gradient_steps': 29000},
{'avg_loss_diffusion': 0.18711430323123932, 'avg_loss_classifier': 72.31799390697479, 'gradient_steps': 30000},
]

# %%
import matplotlib.pyplot as plt

x1 = []
y1 = []
y2 = []
x11 = []
y11 = []
y21 = []

for datum in data:
    x1.append(datum['gradient_steps'])
    y1.append(datum['avg_loss_diffusion'])
    y2.append(datum['avg_loss_classifier'])

for datum in data2:
    x11.append(datum['gradient_steps'])
    y11.append(datum['avg_loss_diffusion'])
    y21.append(datum['avg_loss_classifier'])

plt.plot(x1, y1, label="Diffusion Avg Loss, Standard Janner model", linestyle='-')  # Solid line
plt.plot(x11, y11, label="Diffusion Avg Loss, Reachable Safety Model", linestyle='--')  # Dashed line

plt.xlabel('Gradient Steps')
plt.ylabel('Average Loss')
plt.legend()

plt.show()
